# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('agora.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
missing = df.Transport.median()
df.Transport = df.Transport.fillna(missing)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()
df['Area'] = label.fit_transform(df['Area'])

# %%
x = df.drop(['Profit'],axis=1)
y = df['Profit']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25,random_state=1)

# %%
x_train
# Out:
#     Marketing Spend  Administration  Transport  Area
# 36         28663.76       127056.21  201126.82     2
# 19         86419.70       153514.11  214634.81     1
# 42         23640.93        96189.63  148001.11     0
# 49             0.00       116983.80   45173.06     0
# 26         75328.87       144135.98  134050.07     2
# 22         73994.56       122782.75  303319.26     2
# 13         91992.39       135495.07  252664.93     0
# 41         27892.92        84710.77  164470.71     2
# 17         94657.16       145077.58  282574.31     1
# 45          1000.23       124153.04    1903.93     1
# 24         77044.01        99281.34  140574.81     1
# 23         67532.53       105751.03  304768.73     2
# 4         142107.34        91391.77  366168.42     2
# 33         55493.95       103057.49  214634.81     2
# 14        119943.24       156547.42  256512.92     2
# 30         61994.48       115641.28   91131.24     2
# 10        101913.08       110594.11  229160.95     2
# ...

# %%
x_test
# Out:
#     Marketing Spend  Administration  Transport  Area
# 27         72107.60       127864.55  353183.81     1
# 35         46014.02        85047.44  205517.64     1
# 40         28754.33       118546.05  172795.67     0
# 38         20229.59        65947.93  185265.10     1
# 2         153441.51       101145.55  407934.54     2
# 3         144372.41       118671.85  383199.62     1
# 48           542.05        51743.15       0.00     1
# 29         65605.48       153032.06  107138.38     1
# 46          1315.46       115816.21  297114.46     2
# 31         61136.38       152701.92   88218.23     1
# 32         63408.86       129219.61   46085.25     0
# 39         38558.51        82982.09  174999.30     0
# 21         78389.47       153773.43  299737.29     1

# %% [markdown]
# # Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
scaled_xtrain = minmax.fit_transform(x_train)

# %%
scaled_xtrain
# Out:
# array([[0.17335288, 0.57682456, 0.42631115, 1.        ],
#        [0.52264964, 0.77823604, 0.45494286, 0.5       ],
#        [0.14297577, 0.34185188, 0.31370517, 0.        ],
#        [0.        , 0.50014806, 0.09574943, 0.        ],
#        [0.45557444, 0.70684477, 0.28413435, 1.        ],
#        [0.4475048 , 0.54429273, 0.64291963, 1.        ],
#        [0.55635219, 0.64106561, 0.53555202, 0.        ],
#        [0.16869099, 0.25446874, 0.34861436, 1.        ],
#        [0.57246821, 0.71401273, 0.59894835, 0.5       ],
#        [0.0060492 , 0.5547241 , 0.0040356 , 0.5       ],
#        [0.46594728, 0.3653876 , 0.29796428, 0.5       ],
#        [0.40842369, 0.4146383 , 0.64599195, 1.        ],
#        [0.85943772, 0.30532804, 0.77613557, 1.        ],
#        [0.33561668, 0.39413365, 0.45494286, 1.        ],
#        [0.72539353, 0.8013272 , 0.54370828, 1.        ],
#        [0.37493063, 0.48992809, 0.19316302, 1.        ],
# ...

# %%
scaled_xtest = minmax.transform(x_test)

# %%
scaled_xtest
# Out:
# array([[0.43609283, 0.58297807, 0.74861321, 0.5       ],
#        [0.2782839 , 0.25703165, 0.43561799, 0.5       ],
#        [0.17390063, 0.51204073, 0.36626005, 0.        ],
#        [0.12234465, 0.11163611, 0.39269043, 0.5       ],
#        [0.92798459, 0.37957895, 0.8646636 , 1.        ],
#        [0.87313643, 0.51299839, 0.81223513, 0.5       ],
#        [0.00327821, 0.00350184, 0.        , 0.5       ],
#        [0.39676926, 0.77456642, 0.22709197, 0.5       ],
#        [0.00795565, 0.49125975, 0.62976785, 1.        ],
#        [0.36974101, 0.77205322, 0.18698856, 0.5       ],
#        [0.38348453, 0.5932935 , 0.09768292, 0.        ],
#        [0.23319442, 0.24130912, 0.3709309 , 0.        ],
#        [0.47408436, 0.78021012, 0.63532724, 0.5       ]])

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdc  = StandardScaler()

# %%
scaled_xtrain2 = stdc.fit_transform(x_train)

# %%
scaled_xtrain2
# Out:
# array([[-1.1256156 ,  0.09633061, -0.14282207,  1.14953407],
#        [ 0.17344833,  1.14019267, -0.0244458 ,  0.        ],
#        [-1.2385906 , -1.12147018, -0.6083853 , -1.14953407],
#        [-1.77032949, -0.30106323, -1.50951132, -1.14953407],
#        [-0.07600994,  0.77019074, -0.73064421,  1.14953407],
#        [-0.10602164, -0.0722732 ,  0.75273382,  1.14953407],
#        [ 0.29879095,  0.42927487,  0.30882835, -1.14953407],
#        [-1.14295356, -1.57435368, -0.46405518,  1.14953407],
#        [ 0.35872775,  0.80734034,  0.57093699,  0.        ],
#        [-1.74783202, -0.01821019, -1.88869714,  0.        ],
#        [-0.0374325 , -0.99949078, -0.67346513,  0.        ],
#        [-0.25136756, -0.74423757,  0.76543615,  1.14953407],
#        [ 1.42599144, -1.31076351,  1.30350779,  1.14953407],
#        [-0.52214292, -0.85050769, -0.0244458 ,  1.14953407],
#        [ 0.92746985,  1.25986797,  0.34254992,  1.14953407],
# ...

# %%
scaled_xtest2 = stdc.transform(x_test)

# %%
scaled_xtest2
# Out:
# array([[-0.14846372,  0.12822262,  1.18971812,  0.        ],
#        [-0.73536835, -1.56107081, -0.10434344,  0.        ],
#        [-1.12357847, -0.23942669, -0.39110001, -1.14953407],
#        [-1.31531948, -2.31461715, -0.28182508,  0.        ],
#        [ 1.68092299, -0.9259408 ,  1.66952209,  1.14953407],
#        [ 1.47693807, -0.23446341,  1.45275945,  0.        ],
#        [-1.75813754, -2.87504828, -1.90538209,  0.        ],
#        [-0.29471135,  1.12117401, -0.96648282,  0.        ],
#        [-1.74074177, -0.34712898,  0.69835852,  1.14953407],
#        [-0.39523169,  1.10814877, -1.13228815,  0.        ],
#        [-0.34411839,  0.18168475, -1.50151741, -1.14953407],
#        [-0.90305991, -1.64255651, -0.37178866, -1.14953407],
#        [-0.00717001,  1.1504238 ,  0.72134349,  0.        ]])

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust = RobustScaler()

# %%
scaled_xtrain3 = robust.fit_transform(x_train)

# %%
scaled_xtrain3
# Out:
# array([[-0.71045518,  0.0797609 , -0.17444809,  0.5       ],
#        [ 0.1376803 ,  0.80665804, -0.09039187,  0.        ],
#        [-0.78421453, -0.76825911, -0.50503364, -0.5       ],
#        [-1.13137729, -0.19696575, -1.14490213, -0.5       ],
#        [-0.02518652,  0.54900585, -0.59184683,  0.5       ],
#        [-0.04478062, -0.03764697,  0.46146519,  0.5       ],
#        [ 0.21951424,  0.31160784,  0.1462583 , -0.5       ],
#        [-0.72177482, -1.08362618, -0.4025482 ,  0.5       ],
#        [ 0.25864591,  0.57487511,  0.33237551,  0.        ],
#        [-1.11668909,  0.        , -1.4141531 ,  0.        ],
#        [ 0.        , -0.68331831, -0.5512453 ,  0.        ],
#        [-0.13967436, -0.50557181,  0.47048481,  0.5       ],
#        [ 0.95544318, -0.90007421,  0.85255689,  0.5       ],
#        [-0.31645871, -0.57957339, -0.09039187,  0.5       ],
#        [ 0.6299674 ,  0.88999437,  0.17020321,  0.5       ],
# ...

# %%
scaled_xtest3 = robust.transform(x_test)

# %%
scaled_xtest3
# Out:
# array([[-0.07249028,  0.10196901,  0.77175751,  0.        ],
#        [-0.45566976, -1.0743766 , -0.14712531,  0.        ],
#        [-0.70912518, -0.15404492, -0.35074444, -0.5       ],
#        [-0.83430943, -1.59911133, -0.27315087,  0.        ],
#        [ 1.1218834 , -0.63210151,  1.11245508,  0.5       ],
#        [ 0.98870532, -0.15058872,  0.95853701,  0.        ],
#        [-1.12341738, -1.98936959, -1.4260007 ,  0.        ],
#        [-0.16797273,  0.79341433, -0.7593103 ,  0.        ],
#        [-1.11206   , -0.2290438 ,  0.42285456,  0.5       ],
#        [-0.23360066,  0.78434415, -0.87704479,  0.        ],
#        [-0.2002297 ,  0.13919756, -1.13922584, -0.5       ],
#        [-0.56515257, -1.13111946, -0.3370319 , -0.5       ],
#        [ 0.01975784,  0.81378253,  0.43917565,  0.        ]])

# %% [markdown]
# # Max-abs Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
maxabs = MaxAbsScaler()

# %%
scaled_xtrain4 = maxabs.fit_transform(x_train)

# %%
scaled_xtrain4
# Out:
# array([[0.17335288, 0.69564357, 0.42631115, 1.        ],
#        [0.52264964, 0.84050283, 0.45494286, 0.5       ],
#        [0.14297577, 0.52664642, 0.31370517, 0.        ],
#        [0.        , 0.64049627, 0.09574943, 0.        ],
#        [0.45557444, 0.78915677, 0.28413435, 1.        ],
#        [0.4475048 , 0.67224602, 0.64291963, 1.        ],
#        [0.55635219, 0.74184705, 0.53555202, 0.        ],
#        [0.16869099, 0.46379868, 0.34861436, 1.        ],
#        [0.57246821, 0.79431211, 0.59894835, 0.5       ],
#        [0.0060492 , 0.67974847, 0.0040356 , 0.5       ],
#        [0.46594728, 0.54357379, 0.29796428, 0.5       ],
#        [0.40842369, 0.5789959 , 0.64599195, 1.        ],
#        [0.85943772, 0.50037773, 0.77613557, 1.        ],
#        [0.33561668, 0.56424854, 0.45494286, 1.        ],
#        [0.72539353, 0.85711046, 0.54370828, 1.        ],
#        [0.37493063, 0.63314586, 0.19316302, 1.        ],
# ...

# %%
from sklearn.preprocessing import PowerTransformer

# %%
trs = PowerTransformer(method= 'yeo-johnson') #'Box-Cox' only for positive data

# %%
xtest5 = trs.fit_transform(x_train)

# %%
xtest5
# Out:
# array([[-0.96629335,  0.04618677, -0.01353211,  1.10559551],
#        [ 0.30029624,  1.1773555 ,  0.09294044,  0.12736218],
#        [-1.11609151, -1.13155692, -0.45847705, -1.1874712 ],
#        [-2.38938686, -0.35578257, -1.53380573, -1.1874712 ],
#        [ 0.09551497,  0.76434717, -0.58385583,  1.10559551],
#        [ 0.07004028, -0.12636626,  0.74334983,  1.10559551],
#        [ 0.39896038,  0.39540932,  0.38121971, -1.1874712 ],
#        [-0.98851231, -1.52641112, -0.31549386,  1.10559551],
#        [ 0.4452414 ,  0.80522935,  0.59772277,  0.12736218],
#        [-2.18637358, -0.07135611, -2.32359817,  0.12736218],
#        [ 0.12798096, -1.02102467, -0.52469511,  0.12736218],
#        [-0.05619777, -0.78418984,  0.75339699,  1.10559551],
#        [ 1.19328899, -1.29961423,  1.16534796,  1.10559551],
#        [-0.30596791, -0.88369167,  0.09294044,  1.10559551],
#        [ 0.85972934,  1.31368004,  0.40954101,  1.10559551],
# ...
